# %%
# %pip install plotly
# %pip install plotly.express
# %pip install dash
# %pip install jupyter_dash
# %pip install dash_bootstrap_components

# %%
import plotly_express as px 
import pandas as pd
import plotly
import dash
import jupyter_dash as jd
import dash_core_components as dcc
from dash import html
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output
import base64

image_filename = 'gaLogo.jpg'
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
image2_filename ='me.jpg'
encoded_image2 = base64.b64encode(open(image2_filename, 'rb').read())
colors = {
    'background1': '#45cc84',
    'text': '##ffffff',
    'background2': '#89f5bb',
    'background3': '#FEFEFE'
}

# %%
# the style arguments for the sidebar. We use position:fixed and a fixed width
SIDEBAR_STYLE = {
    "position": "fixed",
    "top": 0,
    "left": 0,
    "bottom": 0,
    "width": "16rem",
    "padding": "2rem 1rem",
    "background-color": "#b3fcff",
}

# the styles for the main content position it to the right of the sidebar and
# add some padding.
CONTENT_STYLE = {
    "margin-left": "18rem",
    "margin-right": "2rem",
    "padding": "2rem 1rem",
}
sidebar = html.Div(
    [
        html.H2("Welcome!", className="display-4"),
        html.Hr(),
        html.P(
            "Navigation Bar", className="lead"
        ),
        dbc.Nav(
            [
                dbc.NavLink("Home", href="/", active="exact"),
                dbc.NavLink("About", href="/about", active="exact"),
                dbc.NavLink("Blog", href="/blog", active="exact"),
                dbc.NavLink("Store", href="/store", active="exact"),
                dbc.NavLink("My Profile", href="/profile", active="exact"),
                dbc.NavLink("Members Only!", href="/store", active="exact"),
                dbc.NavLink("Contact Us", href="/contact", active="exact"),
            ],
            vertical=True,
            pills=True,
        ),
    ],
    style=SIDEBAR_STYLE)
#     html.A[
#             html.Img(
#                 src='data:image/png;base64,{}'.format(encoded_image2.decode()),
#                 style={
#                     'height' : '22%',
#                     'width' : '22%',
#                     'padding-top' : 10,
#                     'padding-right' : 10,
#                     'padding-left' : 10, 
#                     'padding-bottom': 10
#                 }, 
#                 href='https://www.linkedin.com/in/alexvisbal/')]

content = html.Div(style=CONTENT_STYLE, children=[
    html.H1(children='My Website Title'),
    html.P(children='About me: I am a Financial Technology consultant for FIS (Fidelity National Information Systems, and I took this course to better understand how to visualize data and learn software development basics like Object-Oriented Programming and Data Structures. I would say it was a success!'), 
    html.Div(style={'backgroundColor': colors['background2']}, children='''Section 1 of Website'''),
    html.P(children='Content of Section 1 '), 
    html.Div(style={'backgroundColor': colors['background2']}, children='''Section 2 of Website'''),
    html.P(children='Content of Section 1 '),     
    html.A([
            html.Img(
                src='data:image/png;base64,{}'.format(encoded_image.decode()),
                style={
                    'height' : '22%',
                    'width' : '22%',
                    'padding-top' : 10,
                    'padding-right' : 10,
                    'padding-left' : 10, 
                    'padding-bottom': 10
                })], 
                href='https://generalassemb.ly/education/python-programming/atlanta'),
    html.Div(id="page-content", style=CONTENT_STYLE)
    ])

# %%
app = jd.JupyterDash(external_stylesheets=[dbc.themes.BOOTSTRAP])
# app = jd.JupyterDash(__name__, external_stylesheets=external_stylesheets)
server = app.server
colors = {
    'background1': '#45cc84',
    'text': '##ffffff',
    'background2': '#89f5bb',
#     'background3': '#FEFEFE'
# }
app.layout = html.Div([dcc.Location(id="url"), sidebar, content])

# @app.callback(Output('bar-graph', 'figure'),Input('slider', 'value'))
# def update_figure(slider_value):
#     new_df = df.head(slider_value)
#     fig_bar = px.bar(new_df, 
#                      x='PLAYER', 
#                      y=["FGM"], 
#                      labels={'value': 'Field Goals Made'}, 
#                      color="FG_PCT",
#                      title="Player Comparison Bar Chart", 
#                      hover_data=['PLAYER', 'AST', 'STL', 'BLK', 'PTS', 'REB', 'FG_PCT'],
#                      height=700,
#                     )
#     return fig_bar


if __name__ == '__main__':
    app.run_server(mode = 'external', debug = True, port=8051)
# Out:
# Dash is running on http://127.0.0.1:8051/
#
# Dash app running on http://127.0.0.1:8051/
